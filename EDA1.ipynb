# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("data_clean.csv")
print(data)
# Out:
#      Unnamed: 0  Ozone  Solar.R  Wind Temp C Month  Day  Year  Temp Weather
# 0             1   41.0    190.0   7.4     67     5    1  2010    67       S
# 1             2   36.0    118.0   8.0     72     5    2  2010    72       C
# 2             3   12.0    149.0  12.6     74     5    3  2010    74      PS
# 3             4   18.0    313.0  11.5     62     5    4  2010    62       S
# 4             5    NaN      NaN  14.3     56     5    5  2010    56       S
# ..          ...    ...      ...   ...    ...   ...  ...   ...   ...     ...
# 153         154   41.0    190.0   7.4     67     5    1  2010    67       C
# 154         155   30.0    193.0   6.9     70     9   26  2010    70      PS
# 155         156    NaN    145.0  13.2     77     9   27  2010    77       S
# 156         157   14.0    191.0  14.3     75     9   28  2010    75       S
# 157         158   18.0    131.0   8.0     76     9   29  2010    76       C
#
# [158 rows x 10 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  158 non-null    int64
#  1   Ozone       120 non-null    float64
#  2   Solar.R     151 non-null    float64
#  3   Wind        158 non-null    float64
#  4   Temp C      158 non-null    object
#  5   Month       158 non-null    object
#  6   Day         158 non-null    int64
#  7   Year        158 non-null    int64
#  8   Temp        158 non-null    int64
#  9   Weather     155 non-null    object
# dtypes: float64(3), int64(4), object(3)
# memory usage: 12.5+ KB

# %%
#dataframe atrributes
print(type(data))
print(data.shape)
print(data.size)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# (158, 10)
# 1580

# %%
#drop duplicate column(temp c) and unamed column 
data1 = data.drop(['Unnamed: 0',"Temp C"], axis=1)
data1
# Out:
#      Ozone  Solar.R  Wind Month  Day  Year  Temp Weather
# 0     41.0    190.0   7.4     5    1  2010    67       S
# 1     36.0    118.0   8.0     5    2  2010    72       C
# 2     12.0    149.0  12.6     5    3  2010    74      PS
# 3     18.0    313.0  11.5     5    4  2010    62       S
# 4      NaN      NaN  14.3     5    5  2010    56       S
# ..     ...      ...   ...   ...  ...   ...   ...     ...
# 153   41.0    190.0   7.4     5    1  2010    67       C
# 154   30.0    193.0   6.9     9   26  2010    70      PS
# 155    NaN    145.0  13.2     9   27  2010    77       S
# 156   14.0    191.0  14.3     9   28  2010    75       S
# 157   18.0    131.0   8.0     9   29  2010    76       C
#
# [158 rows x 8 columns]

# %%
#convert the month column data type to  float data type
data['Month']=pd.to_numeric(data['Month'],errors='coerce')
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 8 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Ozone    120 non-null    float64
#  1   Solar.R  151 non-null    float64
#  2   Wind     158 non-null    float64
#  3   Month    158 non-null    object
#  4   Day      158 non-null    int64
#  5   Year     158 non-null    int64
#  6   Temp     158 non-null    int64
#  7   Weather  155 non-null    object
# dtypes: float64(3), int64(3), object(2)
# memory usage: 10.0+ KB

# %%
#print all duplicated rows
data1[data1.duplicated(keep = False)]
# Out:
#      Ozone  Solar.R  Wind Month  Day  Year  Temp Weather
# 150   14.0    191.0  14.3     9   28  2010    75       S
# 156   14.0    191.0  14.3     9   28  2010    75       S

# %%
#drop duplicated rows
data1.drop_duplicates(keep='first', inplace = True)
data1
# Out:
#      Ozone  Solar.R  Wind Month  Day  Year  Temp Weather
# 0     41.0    190.0   7.4     5    1  2010    67       S
# 1     36.0    118.0   8.0     5    2  2010    72       C
# 2     12.0    149.0  12.6     5    3  2010    74      PS
# 3     18.0    313.0  11.5     5    4  2010    62       S
# 4      NaN      NaN  14.3     5    5  2010    56       S
# ..     ...      ...   ...   ...  ...   ...   ...     ...
# 152   20.0    223.0  11.5     9   30  2010    68       S
# 153   41.0    190.0   7.4     5    1  2010    67       C
# 154   30.0    193.0   6.9     9   26  2010    70      PS
# 155    NaN    145.0  13.2     9   27  2010    77       S
# 157   18.0    131.0   8.0     9   29  2010    76       C
#
# [157 rows x 8 columns]

# %%
#rename the columns
#CHANGE COLUMN NAME(RENAME THE COLUMNS)
data1.rename({'Solar.R': 'Solar'}, axis=1, inplace = True)
data1
# Out:
#      Ozone  Solar  Wind Month  Day  Year  Temp Weather
# 0     41.0  190.0   7.4     5    1  2010    67       S
# 1     36.0  118.0   8.0     5    2  2010    72       C
# 2     12.0  149.0  12.6     5    3  2010    74      PS
# 3     18.0  313.0  11.5     5    4  2010    62       S
# 4      NaN    NaN  14.3     5    5  2010    56       S
# ..     ...    ...   ...   ...  ...   ...   ...     ...
# 152   20.0  223.0  11.5     9   30  2010    68       S
# 153   41.0  190.0   7.4     5    1  2010    67       C
# 154   30.0  193.0   6.9     9   26  2010    70      PS
# 155    NaN  145.0  13.2     9   27  2010    77       S
# 157   18.0  131.0   8.0     9   29  2010    76       C
#
# [157 rows x 8 columns]

# %%
#imput the missing values
#display the data1 info()
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 157 entries, 0 to 157
# Data columns (total 8 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Ozone    119 non-null    float64
#  1   Solar    150 non-null    float64
#  2   Wind     157 non-null    float64
#  3   Month    157 non-null    object
#  4   Day      157 non-null    int64
#  5   Year     157 non-null    int64
#  6   Temp     157 non-null    int64
#  7   Weather  154 non-null    object
# dtypes: float64(3), int64(3), object(2)
# memory usage: 11.0+ KB

# %%
#display data1 missing values count in each column using isnull().sum()
data1.isnull().sum()
# Out:
# Ozone      38
# Solar       7
# Wind        0
# Month       0
# Day         0
# Year        0
# Temp        0
# Weather     3
# dtype: int64

# %%
#viusalize dat1 missing values using heat map
cols = data1.columns
colors = ['black', 'blue']
sns.heatmap(data1[cols].isnull(),cmap=sns.color_palette(colors),cbar = True)
# Out:
# <Axes: >

# %%
#find the mean and median values of each
median_ozone = data1["Ozone"].median()
mean_ozone = data1["Ozone"].mean()
print("Median of Ozone: ", median_ozone)
print("Mean of Ozone: ", mean_ozone)
# Out:
# Median of Ozone:  31.0
# Mean of Ozone:  41.81512605042017

# %%
#replace the ozone missing values with median value
data1["Ozone"] = data1['Ozone'].fillna(median_ozone)
data1.isnull().sum()
# Out:
# Ozone      0
# Solar      7
# Wind       0
# Month      0
# Day        0
# Year       0
# Temp       0
# Weather    3
# dtype: int64

# %%
#find the mode values of categorcial column(weather)
print(data1["Weather"].value_counts())
mode_weather = data1["Weather"].mode()[0]
print(mode_weather)
# Out:
# Weather
# S     58
# C     49
# PS    47
# Name: count, dtype: int64
# S

# %%
#impute missing values(replace nan with mode etc.) of "weather" using mh=fillnan()
data1["Weather"] = data1["Weather"].fillna(mode_weather)
data1.isnull().sum()
# Out:
# Ozone      0
# Solar      7
# Wind       0
# Month      0
# Day        0
# Year       0
# Temp       0
# Weather    0
# dtype: int64

# %% [markdown]
# detection of outliers in the columns

# %%
#create a figure with two subplots, stacked vertically
fig, axes = plt.subplots(2, 1, figsize=(8,6),gridspec_kw={'height_ratios':[1,3]})
#plot the boxplot un the first (top) subplot
sns.boxplot(data=data1['Ozone'], ax=axes[0], color='orange',width=0.5, orient = 'h')
axes[0].set_title("Boxplot")
axes[0].set_xlabel("Ozone Levels")

sns.histplot(data1["Ozone"], kde=True, ax=axes[1], color='lavender', bins=30)
axes[1].set_title("Histogram with KDE")
axes[1].set_xlabel("Ozone Levels")
axes[1].set_ylabel("Frequency")

plt.tight_layout()
plt.show()

# %% [markdown]
# # Observation
# ##### ->The ozonoe column has extreme valuees beyond 81 as seeen from box plot
# ##### ->The same is confrimed from the below right-skewed histogram

# %%
#create a figure with two subplots, stacked vertically
fig, axes = plt.subplots(2, 1, figsize=(8,6),gridspec_kw={'height_ratios':[1,3]})
#plot the boxplot un the first (top) subplot
sns.boxplot(data=data1['Solar'], ax=axes[0], color='orange',width=0.5, orient = 'h')
axes[0].set_title("Boxplot")
axes[0].set_xlabel("Solar Levels")

sns.histplot(data1["Solar"], kde=True, ax=axes[1], color='blue', bins=30)
axes[1].set_title("Histogram with KDE")
axes[1].set_xlabel("Solar Levels")
axes[1].set_ylabel("Frequency")

plt.tight_layout()
plt.show()

# %% [markdown]
# # Observation
# ##### ->The Solar column does not has extreme values beyond  as seeen from box plot
# ##### ->The same is confrimed from the below right-skewed histogram

# %%
# CREATE A FIGURE FOR VIOLIN PLOT
sns.violinplot(data=data1["Ozone"], color='pink')
plt.title("Violin Plot")
# Out:
# Text(0.5, 1.0, 'Violin Plot')

# %%
plt.figure(figsize=(6,2))
plt.boxplot(data1["Ozone"], vert= False)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1e806882db0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1e8068832c0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1e806882ae0>],
#  'medians': [<matplotlib.lines.Line2D at 0x1e806883800>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1e806883a70>],
#  'means': []}

# %%
#Extract outliers from boxplot for Ozone column 
plt.figure(figsize=(6,2))
boxplot_data = plt.boxplot(data1["Ozone"], vert= False)
[item.get_xdata() for item in boxplot_data['fliers']] #fliers are outliers
# Out:
# [array([115., 135.,  97.,  97.,  85., 108.,  82., 122.,  89., 110., 168.,
#         118.,  84.,  85.,  96.,  91.])]

# %% [markdown]
# # Method 2
# - **Using mu +/- 3*sigma limits (Standard deviation method)

# %%
data1["Ozone"].describe()
# Out:
# count    157.000000
# mean      39.197452
# std       28.781992
# min        1.000000
# 25%       21.000000
# 50%       31.000000
# 75%       45.000000
# max      168.000000
# Name: Ozone, dtype: float64

# %%
mu = data1["Ozone"].describe()[1]
sigma = data1["Ozone"].describe()[2]

for x in data1["Ozone"]:
    if ((x < (mu - 3*sigma)) or (x > (mu + 3*sigma))):
        print(x)
# Out:
# 135.0
# 168.0
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_4584\3121128980.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   mu = data1["Ozone"].describe()[1]
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_4584\3121128980.py:2: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   sigma = data1["Ozone"].describe()[2]

# %% [markdown]
# # Observation
# - It is observed that only teo outliers are identified using standered method
# - In box plot method more no.of outliers are identified
# - This is because the assumption of normality is not satisfied in this column

# %% [markdown]
# ## QUANTILE-QUANTILE PLOT FOR DETECTION OF OUTLIER

# %%
import scipy.stats as stats

#Create Q-Q plot 
plt.figure(figsize=(8,6))
stats.probplot(data1["Ozone"], dist="norm", plot=plt)
plt.title("Q-Q plot for Outlier Detection", fontsize = 14)
plt.xlabel("Theoretical Quantiles",fontsize = 12)
# Out:
# Text(0.5, 0, 'Theoretical Quantiles')

# %% [markdown]
# ## Observations
# - the data does not follow normal distruibution as the data points are ddevitating significantly away from the red line
# - the data shows a right-skewed distribution and possible outliers

# %% [markdown]
# ### Other visualization that could help in the detection of outliers

# %%
# Create a figure for voiln plot 
sns.violinplot(data=data1["Ozone"],color='blue')
plt.title("Violin plot")
# Out:
# Text(0.5, 1.0, 'Violin plot')

# %% [markdown]
# # Other visulizations the could help understand the data
# - (29/01/2025)

# %%
# Create a figure for voiln plot 
sns.violinplot(data=data1["Ozone"],color='purple')
plt.title("Violin plot")

#Show the plot
plt.show()

# %%
sns.swarmplot(data=data1, x = "Weather", y = "Ozone", color="orange",palette="Set2", size=6)
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_4584\466234143.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.swarmplot(data=data1, x = "Weather", y = "Ozone", color="orange",palette="Set2", size=6)
# <Axes: xlabel='Weather', ylabel='Ozone'>

# %%
sns.stripplot(data=data1, x = "Weather", y = "Ozone", color="orange",palette="Set2", size=6, jitter = True)
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_4584\3958730813.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.stripplot(data=data1, x = "Weather", y = "Ozone", color="orange",palette="Set2", size=6, jitter = True)
# <Axes: xlabel='Weather', ylabel='Ozone'>

# %%
sns.kdeplot(data=data1["Ozone"], fill=True, color="blue")#the blue line is known as kde plot
sns.rugplot(data=data1["Ozone"], color="black")#small lines in the graph are rug plot
#we have overlapped the rug plot with the kde plot 
# KDE = Kernal density Estimation plot
# Out:
# <Axes: xlabel='Ozone', ylabel='Density'>

# %%
# WEATHER CATEGORIE PLOT GRAPH
# Catogory wise box plot for ozone
sns.boxplot(data = data1, x = "Weather", y = "Ozone")
# Out:
# <Axes: xlabel='Weather', ylabel='Ozone'>

# %%
# WEATHER CATEGORIE PLOT GRAPH
# Catogory wise box plot for ozone
sns.boxplot(data = data1, y = "Ozone")
# Out:
# <Axes: ylabel='Ozone'>

# %%
# Scatter Plot is a bi-varient plot which require two numeric columns 

# it will not join  any line or any point 
# A SCATTER PLOT (AKA SCATTER CHART, SCATTTER GRAPH) USES DOTS TO REPRESENT VALUES FOR TWO DIFFERNET NUMERIC VARIABLES.SCATTER PLOTS ARE USED TO OBSERVE RELATIONSHIP BETWEEN, VARIABLES.
plt.scatter(data1["Ozone"],data1["Solar"])

# %% [markdown]
# # Correlation coefficient and pair plots
# ###### Correlation is quantified by pear-son correlation co-efficient

# %%
data1.head()
# Out:
#    Ozone  Solar  Wind Month  Day  Year  Temp Weather
# 0   41.0  190.0   7.4     5    1  2010    67       S
# 1   36.0  118.0   8.0     5    2  2010    72       C
# 2   12.0  149.0  12.6     5    3  2010    74      PS
# 3   18.0  313.0  11.5     5    4  2010    62       S
# 4   31.0    NaN  14.3     5    5  2010    56       S

# %%
data1.info() # we can plot scatter plots between two numeric columns
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 157 entries, 0 to 157
# Data columns (total 8 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Ozone    157 non-null    float64
#  1   Solar    150 non-null    float64
#  2   Wind     157 non-null    float64
#  3   Month    157 non-null    object
#  4   Day      157 non-null    int64
#  5   Year     157 non-null    int64
#  6   Temp     157 non-null    int64
#  7   Weather  157 non-null    object
# dtypes: float64(3), int64(3), object(2)
# memory usage: 11.0+ KB

# %%
plt.scatter(data1["Wind"],data1["Temp"])

# %%
#compute pearson correlation coefficient
# between Wind speed and temperature 
data1["Wind"].corr(data1["Temp"])
# Out:
# -0.44122806925588215

# %% [markdown]
# - Correlation is a bi-variant analysis that measure the strength of linear association between two variables and the directions of the relationship correlationn is a statical technique used to determine the degree to which two variables are linear

# %% [markdown]
# #### Observation
# - the correlation between wind and temp is obsserved to be negaitively correlated with mild strength

# %%
# Read all numeric (float) columns into a new table data1_numeric 
data1_numeric = data1.iloc[:,[0,1,2,6]] # only selected columnns
data1_numeric
# Out:
#      Ozone  Solar  Wind  Temp
# 0     41.0  190.0   7.4    67
# 1     36.0  118.0   8.0    72
# 2     12.0  149.0  12.6    74
# 3     18.0  313.0  11.5    62
# 4     31.0    NaN  14.3    56
# ..     ...    ...   ...   ...
# 152   20.0  223.0  11.5    68
# 153   41.0  190.0   7.4    67
# 154   30.0  193.0   6.9    70
# 155   31.0  145.0  13.2    77
# 157   18.0  131.0   8.0    76
#
# [157 rows x 4 columns]

# %%
data1_numeric = data1.iloc[:] # for printing all columns 
data1_numeric
# Out:
#      Ozone  Solar  Wind Month  Day  Year  Temp Weather
# 0     41.0  190.0   7.4     5    1  2010    67       S
# 1     36.0  118.0   8.0     5    2  2010    72       C
# 2     12.0  149.0  12.6     5    3  2010    74      PS
# 3     18.0  313.0  11.5     5    4  2010    62       S
# 4     31.0    NaN  14.3     5    5  2010    56       S
# ..     ...    ...   ...   ...  ...   ...   ...     ...
# 152   20.0  223.0  11.5     9   30  2010    68       S
# 153   41.0  190.0   7.4     5    1  2010    67       C
# 154   30.0  193.0   6.9     9   26  2010    70      PS
# 155   31.0  145.0  13.2     9   27  2010    77       S
# 157   18.0  131.0   8.0     9   29  2010    76       C
#
# [157 rows x 8 columns]

# %%
# print corelation cofefficient for all the above columns
data1_numeric.corr()
# Out:
#           Ozone     Solar      Wind      Temp
# Ozone  1.000000  0.301821 -0.523738  0.597087
# Solar  0.301821  1.000000 -0.057407  0.273558
# Wind  -0.523738 -0.057407  1.000000 -0.441228
# Temp   0.597087  0.273558 -0.441228  1.000000

# %% [markdown]
# ### Observation
# - highest correlation is observed in between ozone and temp with 0.597087
# - the next higher correlation strength is observed between Ozone and wind with -0.523738
# - the next higher correlation strengrth is observed between wind and temp with -0.441228
# - the least correlation strength is observed between solar and wind with -0.057407

# %%
# Plot a pair plot between alll numeric columns using seaborn
sns.pairplot(data1_numeric)

# %% [markdown]
# ### Observation
# - the diagonal are against itself
# - the diagonal plot is symetric in nature above and below the diagonals

# %% [markdown]
# ### Transformations
# - Categorical variables have to be convertes to numerical using a method called One-hot encoding
# - OHE : Pandas, sklearn
# - Pd.get_dummies(df) sklearn.OneHotEncoding
# - we can create a differnt colums using a single column where the diffetent values becomes a single column
# - single column into multiple columns

# %%
#Creating dummy variables for weather column 
data2=pd.get_dummies(data1,columns=['Month','Weather'])
data2
# Out:
#      Ozone  Solar  Wind  Day  Year  Temp  Month_5  Month_6  Month_7  Month_8  \
# 0     41.0  190.0   7.4    1  2010    67     True    False    False    False
# 1     36.0  118.0   8.0    2  2010    72     True    False    False    False
# 2     12.0  149.0  12.6    3  2010    74     True    False    False    False
# 3     18.0  313.0  11.5    4  2010    62     True    False    False    False
# 4     31.0    NaN  14.3    5  2010    56     True    False    False    False
# ..     ...    ...   ...  ...   ...   ...      ...      ...      ...      ...
# 152   20.0  223.0  11.5   30  2010    68    False    False    False    False
# 153   41.0  190.0   7.4    1  2010    67     True    False    False    False
# 154   30.0  193.0   6.9   26  2010    70    False    False    False    False
# 155   31.0  145.0  13.2   27  2010    77    False    False    False    False
# 157   18.0  131.0   8.0   29  2010    76    False    False    False    False
#
# ...

# %% [markdown]
# ### Normalization of data
# - categorical column ohe
# - numerical column scalings i.e, z score scaling the formula {z= x-mu/sigma}
# - 0-1 through normalization and -3 to 3 by standardization

# %%
data2_numeric.values
# Out:
# array([[190. ,   7.4],
#        [118. ,   8. ],
#        [149. ,  12.6],
#        [313. ,  11.5],
#        [  nan,  14.3],
#        [  nan,  14.9],
#        [299. ,   8.6],
#        [ 99. ,  13.8],
#        [ 19. ,  20.1],
#        [194. ,   8.6],
#        [  nan,   6.9],
#        [256. ,   9.7],
#        [290. ,   9.2],
#        [274. ,  10.9],
#        [ 65. ,  13.2],
#        [334. ,  11.5],
#        [307. ,  12. ],
#        [ 78. ,  18.4],
#        [322. ,  11.5],
#        [ 44. ,   9.7],
#        [  8. ,   9.7],
#        [320. ,  16.6],
#        [ 25. ,   9.7],
#        [ 92. ,  12. ],
#        [ 66. ,  16.6],
#        [266. ,  14.9],
#        [  nan,   8. ],
#        [ 13. ,  12. ],
#        [252. ,  14.9],
#        [223. ,   5.7],
#        [279. ,   7.4],
#        [286. ,   8.6],
#        [287. ,   9.7],
#        [242. ,  16.1],
#        [186. ,   9.2],
#        [220. ,   8.6],
#        [264. ,  14.3],
#        [127. ,   9.7],
#        [273. ,   6.9],
#        [291. ,  13.8],
# ...

# %%
# Normalization of data 
from numpy import set_printoptions 
from sklearn.preprocessing import MinMaxScaler

array = data1_numeric.values

scaler = MinMaxScaler(feature_range=(0,1))
rescaledX = scaler.fit_transform(array)

# transformed data
set_printoptions(precision=2)
print(rescaledX[0:10,:])
# Out:
# [[0.24 0.56 0.3  0.27]
#  [0.21 0.34 0.33 0.39]
#  [0.07 0.43 0.57 0.44]
#  [0.1  0.94 0.52 0.15]
#  [0.18  nan 0.66 0.  ]
#  [0.16  nan 0.69 0.24]
#  [0.13 0.89 0.36 0.22]
#  [0.11 0.28 0.64 0.07]
#  [0.04 0.04 0.97 0.12]
#  [0.18 0.57 0.36 0.32]]
